# %%
pwd

# %%
# parsing csv files
import csv

filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    highs = []
    for row in reader:
        high = int(row[5])
        highs.append(high)

print(highs)

# %%
#ploting the data in temp chart 
import csv
import matplotlib.pyplot as plt
from datetime import datetime

filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_07-2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs = [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        dates.append(current_date)
        highs.append(high)

#plot the high temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,highs,c='red')

#format plot
#set the chart title and label axes.
ax.set_title("Daily High Temperatures, July 2018", fontsize=24)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature(F)",fontsize=16)

#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
#ploting the data in temperature chart for whole year
import csv
import matplotlib.pyplot as plt
from datetime import datetime

filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs = [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        dates.append(current_date)
        highs.append(high)

#plot the high temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,highs,c='red')

#format plot
#set the chart title and label axes.
ax.set_title("Daily High Temperatures - 2018", fontsize=24)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature(F)",fontsize=16)

#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
#ploting the data with high and low temperatures
import csv
import matplotlib.pyplot as plt
from datetime import datetime

filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        low = int(row[6])
        dates.append(current_date)
        highs.append(high)
        lows.append(low)

#plot the high temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,highs,c='red')
ax.plot(dates,lows,c='blue')

#format plot
#set the chart title and label axes.
ax.set_title("Daily High and Low Temperatures - 2018", fontsize=24)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature(F)",fontsize=16)

#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
#ploting the data with high and low temperatures and shading an Area
import csv
import matplotlib.pyplot as plt
from datetime import datetime

filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_2018_simple.csv'
with open(filename) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        high = int(row[5])
        low = int(row[6])
        dates.append(current_date)
        highs.append(high)
        lows.append(low)

#plot the high temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,highs,c='red',alpha=0.5)
ax.plot(dates,lows,c='blue',alpha=0.5)
ax.fill_between(dates,highs,lows,facecolor='blue',alpha=0.1)

#format plot
#set the chart title and label axes.
ax.set_title("Daily High and Low Temperatures - 2018", fontsize=24)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature(F)",fontsize=16)

#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
# error checking handling missing data
import csv
from datetime import datetime

file_name = "/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/death_valley_2018_simple.csv"
with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    for index,column_header in enumerate(header_row):
        print(index,column_header)

# %%
# error checking handling missing data
import csv
from datetime import datetime
import matplotlib.pyplot as plt

file_name = "/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/death_valley_2018_simple.csv"
with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        try:
            high = int(row[4])
            low = int(row[5])
        except ValueError:
            print(f"Missing data for {current_date}")
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)
        
#plot the high and low temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,highs,c='red',alpha=0.5)
ax.plot(dates,lows,c='blue',alpha=0.5)
ax.fill_between(dates,highs,lows,facecolor='blue',alpha=0.1)

#format plot
#set the chart title and label axes.
title = "Daily High and Low Temperatures - 2018\n Death Valley, CA"
ax.set_title(title, fontsize=20)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Temperature(F)",fontsize=16)


#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
# try it yourself - rainfall in sitka
import csv 
from datetime import datetime
import matplotlib.pyplot as plt 


file_name = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_2018_simple.csv'

with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    dates,rainfall_measures = [],[]
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        try:
            rainfall = float(row[3])
        except ValueError:
            print(f"Missing data for {rainfall}")
        else:
            dates.append(current_date)
            rainfall_measures.append(rainfall)
            
#plot the high and low temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,rainfall_measures,c='blue',alpha=0.5)

#format plot
#set the chart title and label axes.
title = "Daily Rainfall - 2018\n Sitka Valley, CA"
ax.set_title(title, fontsize=20)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Rainfall(cms)",fontsize=16)

#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
# try it yourself - rainfall in sitka
import csv 
from datetime import datetime
import matplotlib.pyplot as plt 


file_name = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/death_valley_2018_simple.csv'

with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    dates,rainfall_measures = [],[]
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        try:
            rainfall = float(row[3])
        except ValueError:
            print(f"Missing data for {rainfall}")
        else:
            dates.append(current_date)
            rainfall_measures.append(rainfall)
            
#plot the high and low temp.
plt.style.use('seaborn-whitegrid')
fig,ax = plt.subplots()
ax.plot(dates,rainfall_measures,c='blue',alpha=0.5)

#format plot
#set the chart title and label axes.
title = "Daily Rainfall - 2018\n Sitka Valley, CA"
ax.set_title(title, fontsize=20)
ax.set_xlabel("",fontsize=16)
fig.autofmt_xdate()
ax.set_ylabel("Rainfall(cms)",fontsize=16)

#set size of the tick labels 
ax.tick_params(axis='both',which = 'major', labelsize=16)

plt.show()

# %%
# try it yourself - comparison 
# error checking handling missing data
import csv
from datetime import datetime
import matplotlib.pyplot as plt

file_name = "/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/death_valley_2018_simple.csv"
with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%Y-%m-%d')
        try:
            high = int(row[4])
            low = int(row[5])
        except ValueError:
            print(f"Missing data for {current_date}")
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)

# Plot the high and low temperatures.
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red', alpha=0.5)
ax.plot(dates, lows, c='blue', alpha=0.5)
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
title = "Daily High and Low Temperatures - 2018\n Sikta vs Death Valley, CA"
ax.set_title(title, fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(10, 130)

plt.show()

# %%
# try it yourself comparing weather in SFO and Sitka
import csv 
from datetime import datetime 
import matplotlib.pyplot as plt

file_name = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sanfransico_weather_2018_simple.csv'
with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    #get the high temperature from the file. 
    dates, highs, lows = [], [], []
    for row in reader:
        current_date = datetime.strptime(row[2], '%m/%d/%y')
        try:
            high = int(row[4])
            low = int(row[5])
        except ValueError:
            print(f"Missing data for {current_date}")
        else:
            dates.append(current_date)
            highs.append(high)
            lows.append(low)


# Plot the high and low temperatures.
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red', alpha=0.5)
ax.plot(dates, lows, c='blue', alpha=0.5)
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.1)

# Format plot.
title = "Daily High and Low Temperatures - 2018\n Sanfransico, CA"
ax.set_title(title, fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(10, 130)

plt.show()

# %%
# comparing sikate and death valley weather data in same cell 

import csv 
from datetime import datetime 
import matplotlib.pyplot as plt 


def get_weatherdata(filename,dates,highs,lows,date_index,high_index,low_index):
    """ Get weather data by passing appropriate parameters"""
    with open(file_name) as f:
        reader = csv.reader(f)
        header_row = next(reader)
    
        #get the high temperature from the file. 
        for row in reader:
            current_date = datetime.strptime(row[date_index], '%m/%d/%y')
            try:
                high = int(row[high_index])
                low = int(row[low_index])
            except ValueError:
                print(f"Missing data for {current_date}")
            else:
                dates.append(current_date)
                highs.append(high)
                lows.append(low)
            
# Get weather data for Sitka.
filename = '/data/sitka_weather_2018_simple.csv'
dates, highs, lows = [], [], []
get_weatherdata(filename,dates,highs,lows,date_index=2,high_index=4,low_index=5)

# Plot Sitka weather data.
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='green', alpha=0.6)
ax.plot(dates, lows, c='yellow', alpha=0.6)
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.15)

# Get weather data for Sanfransico.
filename = '/data/sanfransico_weather_2018_simple.csv'
dates, highs, lows = [], [], []
get_weatherdata(filename,dates,highs,lows,date_index=2,high_index=4,low_index=5)

# Plot Sanfransico weather data.
ax.plot(dates, highs, c='red', alpha=0.3)
ax.plot(dates, lows, c='blue', alpha=0.3)
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.15)



# Format plot.
title = "Daily high and low temperatures - 2018"
title += "\nSitka, AK and Sanfransico, CA"
plt.title(title, fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(10, 130)

plt.show()

# %%
import csv
from datetime import datetime

from matplotlib import pyplot as plt

def get_weather_data(filename, dates, highs, lows, date_index, high_index,
        low_index):
    """Get the highs and lows from a data file."""
    with open(filename) as f:
        reader = csv.reader(f)
        header_row = next(reader)

        # Get dates, and high and low temperatures from this file.
        for row in reader:
            current_date = datetime.strptime(row[date_index], '%Y-%m-%d')
            try:
                high = int(row[high_index])
                low = int(row[low_index])
            except ValueError:
                print(f"Missing data for {current_date}")
            else:
                dates.append(current_date)
                highs.append(high)
                lows.append(low)

# Get weather data for Sitka.
filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/sitka_weather_2018_simple.csv'
dates, highs, lows = [], [], []
get_weather_data(filename, dates, highs, lows, date_index=2, high_index=5,
        low_index=6)

# Plot Sitka weather data.
plt.style.use('seaborn')
fig, ax = plt.subplots()
ax.plot(dates, highs, c='red', alpha=0.6)
ax.plot(dates, lows, c='blue', alpha=0.6)
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.15)

# Get weather data for Death Valley.
filename = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/death_valley_2018_simple.csv'
dates, highs, lows = [], [], []
get_weather_data(filename, dates, highs, lows, date_index=2, high_index=4,
        low_index=5)

# Add Death Valley data to current plot.
ax.plot(dates, highs, c='red', alpha=0.3)
ax.plot(dates, lows, c='blue', alpha=0.3)
plt.fill_between(dates, highs, lows, facecolor='blue', alpha=0.05)

# Format plot.
title = "Daily high and low temperatures - 2018"
title += "\nSitka, AK and Death Valley, CA"
plt.title(title, fontsize=24)
plt.xlabel('', fontsize=16)
fig.autofmt_xdate()
plt.ylabel("Temperature (F)", fontsize=16)
plt.tick_params(axis='both', which='major', labelsize=16)
plt.ylim(10, 130)

plt.show()

# %%
# mapping global datasets with JSON module and making a readable file
import json 

#explore the structure of the json data
file_name = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/mapping/eq_data_1_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)
    
readable_file = 'data/mapping/readable_eq_data.json'
with open(readable_file,'w') as f:
    json.dump(all_eq_data,f,indent=4)

# %%
# making a list of all earth quakes
import json 

#explore the structure of the data
file_name = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/mapping/eq_data_1_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
print(len(all_eq_dicts))

# %%
# extracting Magnitudes
import json 

#explore the structure of the data
file_name = '/Users/sundarsritharan/Python/pc2e/projects/data_visulization/data/mapping/eq_data_1_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
mags = []

#looping all earth quake list 
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    mags.append(mag)

print(mags[:10])

# %%
# extracting Magnitudes, longitude and latitude 

file_name = 'data/mapping/eq_data_1_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
    
mags = []
lons = []
lats = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

print(mags[:10])
print(lons[:10])
print(lats[:10])

# %%
# Building a world map 
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_1_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
    
mags = []
lons = []
lats = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

#map the earth quake 

data = [Scattergeo(lon=lons,lat=lats)]
my_layout = Layout(title='Global Earthquakes')

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
# customizing marker size 
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_1_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
    
mags = []
lons = []
lats = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon' : lons,
    'lat' : lats,
    'marker' : {
        'size' : [4*mag for mag in mags],
    },
}]
my_layout = Layout(title='Global Earthquakes')

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
# customizing marker colors
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_30_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
    
mags = []
lons = []
lats = []
for eq_dict in all_eq_dicts:
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon' : lons,
    'lat' : lats,
    'marker' : {
        'size' : [4*mag for mag in mags],
    'color': mags,
    'colorscale' : 'Viridis',
    'reversescale' : True,
    'colorbar' : {'title' : 'Magnitude'}
    },
}]
my_layout = Layout(title='Global Earthquakes')

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
# publish more info about the markers
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_30_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
    
mags,lons,lats,hover_texts = [],[],[],[]
for eq_dict in all_eq_dicts:
    title = eq_dict['properties']['title']
    mag = eq_dict['properties']['mag']
    lon = eq_dict['geometry']['coordinates'][0]
    lat = eq_dict['geometry']['coordinates'][1]
    mags.append(mag)
    lons.append(lon)
    lats.append(lat)
    hover_texts.append(title)

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon' : lons,
    'lat' : lats,
    'text' : hover_texts,
    'marker' : {
        'size' : [4*mag for mag in mags],
    'color': mags,
    'colorscale' : 'Viridis',
    'reversescale' : True,
    'colorbar' : {'title' : 'Magnitude'}
    },
}]
my_layout = Layout(title='Global Earthquakes')

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
#refactring
# publish more info about the markers
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_30_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
    
mags,lons,lats,hover_texts = [],[],[],[]
for eq_dict in all_eq_dicts:
    mags.append(eq_dict['properties']['mag'])
    lons.append(eq_dict['geometry']['coordinates'][0])
    lats.append(eq_dict['geometry']['coordinates'][1])
    hover_texts.append(eq_dict['properties']['title'])

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon' : lons,
    'lat' : lats,
    'text' : hover_texts,
    'marker' : {
        'size' : [4*mag for mag in mags],
    'color': mags,
    'colorscale' : 'Viridis',
    'reversescale' : True,
    'colorbar' : {'title' : 'Magnitude'}
    },
}]
my_layout = Layout(title='Global Earthquakes')

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
# automated title 
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_30_day_m1.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
plot_title = all_eq_data['metadata']['title']
    
mags,lons,lats,hover_texts = [],[],[],[]
for eq_dict in all_eq_dicts:
    mags.append(eq_dict['properties']['mag'])
    lons.append(eq_dict['geometry']['coordinates'][0])
    lats.append(eq_dict['geometry']['coordinates'][1])
    hover_texts.append(eq_dict['properties']['title'])

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon' : lons,
    'lat' : lats,
    'text' : hover_texts,
    'marker' : {
        'size' : [4*mag for mag in mags],
    'color': mags,
    'colorscale' : 'Viridis',
    'reversescale' : True,
    'colorbar' : {'title' : 'Magnitude'}
    },
}]
my_layout = Layout(title=plot_title)

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
# earth quakes yesterday
import json 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

file_name = 'data/mapping/eq_data_1_yesterday_m1.geo.json'

with open(file_name) as f:
    all_eq_data = json.load(f)

all_eq_dicts = all_eq_data['features']
plot_title = all_eq_data['metadata']['title']
    
mags,lons,lats,hover_texts = [],[],[],[]
for eq_dict in all_eq_dicts:
    mags.append(eq_dict['properties']['mag'])
    lons.append(eq_dict['geometry']['coordinates'][0])
    lats.append(eq_dict['geometry']['coordinates'][1])
    hover_texts.append(eq_dict['properties']['title'])

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon' : lons,
    'lat' : lats,
    'text' : hover_texts,
    'marker' : {
        'size' : [4*mag for mag in mags],
    'color': mags,
    'colorscale' : 'Viridis',
    'reversescale' : True,
    'colorbar' : {'title' : 'Magnitude'}
    },
}]
my_layout = Layout(title=plot_title)

fig = {'data' : data, 'layout': my_layout}
offline.plot(fig, filename = 'global_earthquakes.html')

# %%
# plotting world fire data 

import csv 
from datetime import datetime 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

num_rows = 10_000

file_name = 'data/mapping/world_fires_1_day.csv'

with open(file_name) as f:
    reader = csv.reader(f)
    header_row = next(reader)
    
    
    #get the high temperature from the file. 
    dates, brightnesses = [], []
    lats, lons = [], []
    hover_texts = []
    row_num = 0
    for row in reader:
        date = datetime.strptime(row[5], '%Y-%m-%d')
        brightness = float(row[2])
        label = f"{date.strftime('%m/%d/%y')} - {brightness}"
        
        dates.append(date)
        brightnesses.append(brightness)
        lats.append(row[0])
        lons.append(row[1])
        hover_texts.append(label)
        
        print(brightness)
        
        row_num += 1
        if row_num == num_rows:
            break

# %%
# plotting world fire data 

import csv 
from datetime import datetime 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

num_rows = 10_000

file_name = 'data/mapping/world_fires_1_day.csv'

with open(file_name) as f:
    reader = csv.reader(f)
    header_rows = next(reader)
    
    #get data
    dates,brightnesses = [],[]
    lons,lats = [],[]
    hover_texts = []
    row_num = 0
    
    for row in reader:
        date = datetime.strptime(row[5], '%Y-%m-%d')
        brightness = float(row[2])
        hover_text = f"{date.strftime('%m/%d/%y')} - {brightness}"
        
        brightnesses.append(brightness)
        lons.append(row[1])
        lats.append(row[0])
        hover_texts.append(hover_text)
        
        
        
        row_num += 1
        if num_rows == row_num:
            break

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon': lons,
    'lat': lats,
    'text': hover_texts,
    'marker': {
        'size': [brightness/20 for brightness in brightnesses],
        'color': brightnesses,
        'colorscale': 'YlOrRd',
        'reversescale': True,
        'colorbar': {'title': 'Brightness'},
    },
}]

my_layout = Layout(title='Global Fire Activity')

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename = 'global_wildfires.html')
# Out:
# 'global_wildfires.html'

# %%
# plotting world fire data for yesterday

import csv 
from datetime import datetime 

from plotly.graph_objs import Scattergeo, Layout
from plotly import offline 

num_rows = 10_000

file_name = 'data/mapping/world_fires_yesterday.csv'

with open(file_name) as f:
    reader = csv.reader(f)
    header_rows = next(reader)
    
    #get data
    dates,brightnesses = [],[]
    lons,lats = [],[]
    hover_texts = []
    row_num = 0
    
    for row in reader:
        date = datetime.strptime(row[5], '%Y-%m-%d')
        brightness = float(row[2])
        hover_text = f"{date.strftime('%m/%d/%y')} - {brightness}"
        
        brightnesses.append(brightness)
        lons.append(row[1])
        lats.append(row[0])
        hover_texts.append(hover_text)
        
        
        
        row_num += 1
        if num_rows == row_num:
            break

#map the earth quake and format the data
data = [{
    'type': 'scattergeo',
    'lon': lons,
    'lat': lats,
    'text': hover_texts,
    'marker': {
        'size': [brightness/20 for brightness in brightnesses],
        'color': brightnesses,
        'colorscale': 'YlOrRd',
        'reversescale': True,
        'colorbar': {'title': 'Brightness'},
    },
}]

my_layout = Layout(title='Global Fire Activity')

fig = {'data': data, 'layout': my_layout}
offline.plot(fig, filename = 'global_wildfires.html')
# Out:
# 'global_wildfires.html'
