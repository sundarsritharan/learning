# %%
#processing an API response 

import requests

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#store the API response in a variable 
response_dict = r.json()

#process the results/ 
print(response_dict.keys())

# %%
#working with the response dictionaries 

import requests 

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#store the API response in dictionary
response_dict = r.json()
print(f"Total Repositories: {response_dict['total_count']}")

#explore the information about the repositories
repo_dicts = response_dict['items']
print(f"Repositories Returned: {len(repo_dicts)}")



#examine the first repository 
repo_dict = repo_dicts[0]
print(f"\nKeys: {len(repo_dict)}")
for key in sorted(repo_dict.keys()):
    print(key)
# Out:
# Status Code: 200
# Total Repositories: 5948308
# Repositories Returned: 30
#
# Keys: 74
# archive_url
# archived
# assignees_url
# blobs_url
# branches_url
# clone_url
# collaborators_url
# comments_url
# commits_url
# compare_url
# contents_url
# contributors_url
# created_at
# default_branch
# deployments_url
# description
# disabled
# downloads_url
# events_url
# fork
# forks
# forks_count
# forks_url
# full_name
# git_commits_url
# git_refs_url
# git_tags_url
# git_url
# has_downloads
# has_issues
# has_pages
# has_projects
# has_wiki
# homepage
# hooks_url
# html_url
# id
# issue_comment_url
# issue_events_url
# issues_url
# keys_url
# labels_url
# language
# languages_url
# license
# merges_url
# milestones_url
# mirror_url
# name
# node_id
# notifications_url
# open_issues
# open_issues_count
# owner
# private
# pulls_url
# pushed_at
# releases_url
# score
# size
# ssh_url
# stargazers_count
# stargazers_url
# statuses_url
# subscribers_url
# subscription_url
# svn_url
# tags_url
# teams_url
# trees_url
# updated_at
# url
# watchers
# watchers_count

# %%
#working with the response dictionaries more information

import requests 

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#store the API response in dictionary
response_dict = r.json()
print(f"Total Repositories: {response_dict['total_count']}")

#explore the information about the repositories
repo_dicts = response_dict['items']
print(f"Repositories Returned: {len(repo_dicts)}")

#examine the first repository 
repo_dict = repo_dicts[0]

print("\nSelected information about the first repository:")
print(f"Name: {repo_dict['name']}")
print(f"Owner: {repo_dict['owner']['login']}")
print(f"Stars: {repo_dict['stargazers_count']}")
print(f"Repository: {repo_dict['html_url']}")
print(f"Created: {repo_dict['created_at']}")
print(f"Updated: {repo_dict['updated_at']}")
print(f"Description: {repo_dict['description']}")

# %%
# Summarizing the top repositories 

import requests 

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#store the API response in dictionary
response_dict = r.json()
print(f"Total Repositories: {response_dict['total_count']}")

#explore the information about the repositories
repo_dicts = response_dict['items']
print(f"Repositories Returned: {len(repo_dicts)}")

print("\nSelected information about the first repository:")

repo_info_count = 0
for repo_dict in repo_dicts:
    print(f"Name: {repo_dict['name']}")
    print(f"Owner: {repo_dict['owner']['login']}")
    print(f"Stars: {repo_dict['stargazers_count']}")
    print(f"Repository: {repo_dict['html_url']}")
    print(f"Description: {repo_dict['description']}")
    repo_info_count += 1

# %%
# Visulizing top repositories 

import requests
from plotly.graph_objs import bar
from plotly import offline 

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#process results
response_dict = r.json()
repo_dicts = response_dict['items']
repo_names, stars = [],[]
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

#makes visulization
data = [{
    'type':'bar',
    'x': repo_names,
    'y' : stars,
}]

my_layout = {
    'title' : 'Most-Starred Python Projects on Github',
    'xaxis' :{'title':'Repository'},
    'yaxis' :{'title':'Stars'},
}

fig = {'data':data, 'layout':my_layout}
offline.plot(fig,filename='python_repos.html')
# Out:
# Status Code: 200
# 'python_repos.html'

# %%
# Refining the colors

import requests
from plotly.graph_objs import bar
from plotly import offline 

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#process results
response_dict = r.json()
repo_dicts = response_dict['items']
repo_names, stars = [],[]
for repo_dict in repo_dicts:
    repo_names.append(repo_dict['name'])
    stars.append(repo_dict['stargazers_count'])

#makes visulization
data = [{
    'type':'bar',
    'x': repo_names,
    'y' : stars,
    'marker': {
        'color' : 'rgb(60,100,150)',
        'line': {'width':1.5,'color': 'rgb(25,25,25)'}
    },
    'opacity': 0.6,
}]

my_layout = {
    'title' : 'Most-Starred Python Projects on Github',
    'title_font' : {'size':28},
    'xaxis' :{
        'title':'Repository',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
    'yaxis' :{
        'title':'Stars',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
}

fig = {'data':data, 'layout':my_layout}
offline.plot(fig,filename='python_repos.html')
# Out:
# Status Code: 200
# 'python_repos.html'

# %%
#Adding custom tool tips and repo links
import requests
from plotly.graph_objs import bar
from plotly import offline 

url = 'https://api.github.com/search/repositories?q=language:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#process results
response_dict = r.json()
repo_dicts = response_dict['items']
repo_links, stars,labels = [],[],[]
for repo_dict in repo_dicts:
    repo_name = repo_dict['name']
    repo_url = repo_dict['html_url']
    repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
    repo_links.append(repo_link)
    stars.append(repo_dict['stargazers_count'])
    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    label = f"{owner} <br />{description}"
    labels.append(label)

#makes visulization
data = [{
    'type':'bar',
    'x': repo_links,
    'y' : stars,
    'hovertext': labels,
    'marker': {
        'color' : 'rgb(60,100,150)',
        'line': {'width':1.5,'color': 'rgb(25,25,25)'}
    },
    'opacity': 0.6,
}]

my_layout = {
    'title' : 'Most-Starred Python Projects on Github',
    'title_font' : {'size':28},
    'xaxis' :{
        'title':'Repository',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
    'yaxis' :{
        'title':'Stars',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
}

fig = {'data':data, 'layout':my_layout}
offline.plot(fig,filename='python_repos.html')
# Out:
# Status Code: 200
# 'python_repos.html'

# %%
# the hacker news API 
import requests
import json 

url = 'https://hacker-news.firebaseio.com/v0/item/19155826.json'
r = requests.get(url)
print(f"Status Code: {r.status_code}")

#explore the structure of the json 
response_dict = r.json()
readable_file = 'data/readable_hn_data.json'

with open (readable_file,'w') as f:
    json.dump(response_dict,f,indent=4)
# Out:
# Status Code: 200

# %%
# the hacker news API all submissions 

from operator import itemgetter
import requests

#make an API call and store the response.
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Request Status: {r.status_code}")

#process the information about each submission. 
submission_ids = r.json()
submission_dicts = []

for submission_id in submission_ids[:15]:
    #make a separate API call for each submission 
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    r = requests.get(url)
    print(f"id: {submission_id} \n Status:{r.status_code}")
    
    response_dict = r.json()
    
    #build a dictionary of each submission 
    submission_dict = {
        'title' : response_dict['title'],
        'hn_link': f"https://hacker-news.firebaseio.com/item?id={submission_id}",
        'comments': response_dict['descendants'],
    }
    submission_dicts.append(submission_dict)
    

submission_dicts = sorted(submission_dicts,key=itemgetter('comments'),reverse=True)
    
for submission_dict in submission_dicts:
    print(f"\nTitle: {submission_dict['title']}")
    print(f"Discussion Link: {submission_dict['hn_link']}")
    print(f"Comments: {submission_dict['comments']}")
# Out:
# Request Status: 200
# id: 24890988
#  Status:200
# id: 24891947
#  Status:200
# id: 24890463
#  Status:200
# id: 24886909
#  Status:200
# id: 24889973
#  Status:200
# id: 24892297
#  Status:200
# id: 24890167
#  Status:200
# id: 24887381
#  Status:200
# id: 24886039
#  Status:200
# id: 24877034
#  Status:200
# id: 24889970
#  Status:200
# id: 24877635
#  Status:200
# id: 24888234
#  Status:200
# id: 24889488
#  Status:200
# id: 24890440
#  Status:200
#
# Title: I am seriously considering going back to desktop computers
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24889488
# Comments: 360
#
# Title: Nearly 12M Square Feet of Vacant Office Space in S.F
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24889970
# Comments: 327
#
# Title: Washington crews destroy first U.S. “murder hornet” nest
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24886909
# Comments: 292
#
# Title: Hackers hijack and publish mental health data of hundreds of people
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24886039
# Comments: 280
#
# Title: Apple, Google and a Deal That Controls the Internet
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24887381
# Comments: 235
#
# Title: New nuclear engine concept could help realize 3-month trips to Mars
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24890988
# Comments: 110
#
# Title: Standard ML in 2020
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24890463
# Comments: 62
#
# Title: A one-line change decreased our build times by 99%
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24877034
# Comments: 59
#
# Title: Mexican Chernobyl, the Biggest Nuclear Accident in the American Continent (2019)
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24891947
# Comments: 25
#
# Title: Adobe XD for Visual Studio Code
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24877635
# Comments: 25
#
# Title: Using FOIA Data and Unix to halve major source of parking tickets (2018)
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24889973
# Comments: 16
#
# Title: The RIAA's fraudulent attack on YouTube-dl is not a DMCA §512 infringement
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24888234
# Comments: 12
#
# Title: After 14 years a new printed UK Amiga magazine
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24890167
# Comments: 6
#
# Title: When the Worst Man in the World Writes a Masterpiece
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24890440
# Comments: 3
#
# Title: An Intuition for Lisp Syntax
# Discussion Link: https://hacker-news.firebaseio.com/item?id=24892297
# Comments: 0

# %%
#Visulizing popular Github repos for languages
import requests
from plotly.graph_objs import bar
from plotly import offline 

language = 'go'

url = f'https://api.github.com/search/repositories?q={language}:python&sort=stars'
headers = {'Accept': 'application/vnd.github.v3+json'}
r = requests.get(url,headers=headers)
print(f"Status Code: {r.status_code}")

#process results
response_dict = r.json()
repo_dicts = response_dict['items']
repo_links, stars,labels = [],[],[]
for repo_dict in repo_dicts:
    repo_name = repo_dict['name']
    repo_url = repo_dict['html_url']
    repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
    repo_links.append(repo_link)
    stars.append(repo_dict['stargazers_count'])
    owner = repo_dict['owner']['login']
    description = repo_dict['description']
    label = f"{owner} <br />{description}"
    labels.append(label)

#makes visulization
data = [{
    'type':'bar',
    'x': repo_links,
    'y' : stars,
    'hovertext': labels,
    'marker': {
        'color' : 'rgb(60,100,150)',
        'line': {'width':1.5,'color': 'rgb(25,25,25)'}
    },
    'opacity': 0.6,
}]

title = f"Most-Starred {language.title()} Projects on Github"

my_layout = {
    'title' : title,
    'title_font' : {'size':28},
    'xaxis' :{
        'title':'Repository',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
    'yaxis' :{
        'title':'Stars',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
}

fig = {'data':data, 'layout':my_layout}
offline.plot(fig,filename='python_repos.html')
# Out:
# Status Code: 200
# 'python_repos.html'

# %%
#Try it yourself active discussions 
from operator import itemgetter
import requests
from plotly.graph_objs import bar
from plotly import offline

#make an API call and store the response.
url = 'https://hacker-news.firebaseio.com/v0/topstories.json'
r = requests.get(url)
print(f"Request Status: {r.status_code}")

#process the information about each submission. 
submission_ids = r.json()
submission_dicts = []

for submission_id in submission_ids[:15]:
    #make a separate API call for each submission 
    url = f"https://hacker-news.firebaseio.com/v0/item/{submission_id}.json"
    r = requests.get(url)
    print(f"id: {submission_id} \n Status:{r.status_code}")
    
    response_dict = r.json()
    
    #build a dictionary of each submission 
    submission_dict = {
        'title' : response_dict['title'],
        'hn_link': f"https://hacker-news.firebaseio.com/item?id={submission_id}",
        'comments': response_dict['descendants'],
        'url': response_dict['url'],
    }
    submission_dicts.append(submission_dict)
    

submission_dicts = sorted(submission_dicts,key=itemgetter('comments'),reverse=True)
    
    
submission_links, comments = [],[]
for submission_dict in submission_dicts:
    submission_title = submission_dict['title']
    submission_url = submission_dict['url']
    submission_link = f"<a href='{submission_url}'>{submission_title}</a>"
    submission_links.append(submission_link)
    comments.append(submission_dict['comments'])
    labels.append(submission_dict['title'])
    
    
#makes visulization
data = [{
    'type':'bar',
    'x': submission_links,
    'y' : comments,
    'marker': {
        'color' : 'rgb(60,100,150)',
        'line': {'width':1.5,'color': 'rgb(25,25,25)'}
    },
    'opacity': 0.6,
}]

title = f"Most-Discussed Hacker News Titles"

my_layout = {
    'title' : title,
    'title_font' : {'size':28},
    'xaxis' :{
        'title':'Repository',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
    'yaxis' :{
        'title':'Stars',
        'titlefont':{'size':24},
        'tickfont':{'size':14},
    },
}

fig = {'data':data, 'layout':my_layout}
offline.plot(fig,filename='hacker_titles.html')
# Out:
# Request Status: 200
# id: 24890988
#  Status:200
# id: 24892297
#  Status:200
# id: 24890463
#  Status:200
# id: 24886909
#  Status:200
# id: 24889973
#  Status:200
# id: 24891947
#  Status:200
# id: 24890167
#  Status:200
# id: 24887381
#  Status:200
# id: 24877034
#  Status:200
# id: 24886039
#  Status:200
# id: 24877635
#  Status:200
# id: 24888234
#  Status:200
# id: 24889970
#  Status:200
# id: 24889488
#  Status:200
# id: 24890440
#  Status:200
# 'hacker_titles.html'

# %%
        language = 'python'
        url = f'https://api.github.com/search/repositories?q={language}:python&sort=stars'
        headers = {'Accept': 'application/vnd.github.v3+json'}
        r = requests.get(url,headers=headers)
        response_dict = r.json()
        print(type(response_dict))
# Out:
# <class 'dict'>

# %%
# test python git visualization 
import unittest
import random
from python_repos import requests


class PythonReposTestCase(unittest.TestCase):
    """ test status code, number of repos, items returned """

    def Setup(self):
        """ Setup up API access to Github and use the response for testing """
        
        
    
    def test_status_code(self):
        """ does a simple test to check the status code of api call """
        print('hello')
        #self.assertEqual(r.status_code,200)

if __name__ == '__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False)
# Out:
# .
# hello
# ----------------------------------------------------------------------
# Ran 1 test in 0.002s
#
# OK

# %%
# try it yourself. Perfect code for Github visualization 
import requests
from plotly.graph_objs import bar
from plotly import offline 

def get_response(language):
    """Make an API call to Github and return the reponse"""
    url = f'https://api.github.com/search/repositories?q=language:{language}&sort=star'
    headers = {'Accept': 'application/vnd.github.v3+json'}
    r = requests.get(url,headers=headers)
    return r

def get_repo_dicts(r):
    """ Return a set of dicts representing the most popular repositories. """
    response_dict = r.json()
    repo_dict = response_dict['items']
    return repo_dicts
   
def get_project_data(repo_dicts):
    """Return data needed for each project in visualization."""
    repo_links, stars, labels = [], [], []
    for repo_dict in repo_dicts:
        repo_name = repo_dict['name']
        repo_url = repo_dict['html_url']
        repo_link = f"<a href='{repo_url}'>{repo_name}</a>"
        repo_links.append(repo_link)

        stars.append(repo_dict['stargazers_count'])

        owner = repo_dict['owner']['login']
        description = repo_dict['description']
        label = f"{owner}<br />{description}"
        labels.append(label)

    return repo_links, stars, labels

def make_visualization(repo_links, stars, labels):
    """Generate the visualization of most commented articles."""
    data = [{
        'type': 'bar',
        'x': repo_links,
        'y': stars,
        'hovertext': labels,
        'marker': {
            'color': 'rgb(60, 100, 150)',
            'line': {'width': 1.5, 'color': 'rgb(25, 25, 25)'}
        },
        'opacity': 0.6,
    }]

    my_layout = {
        'title': 'Most-Starred Python Projects on GitHub',
        'titlefont': {'size': 28},
        'xaxis': {
            'title': 'Repository',
            'titlefont': {'size': 24},
            'tickfont': {'size': 14},
        },
        'yaxis': {
            'title': 'Stars',
            'titlefont': {'size': 24},
            'tickfont': {'size': 14},
        },

    }

    fig = {'data': data, 'layout': my_layout}
    offline.plot(fig, filename='python_repos.html')
    

if __name__ == '__main__':
    response = get_response('python')
    repo_dicts = get_repo_dicts(response)
    repo_links, stars, labels = get_project_data(repo_dicts)
    make_visualization(repo_links, stars, labels)
